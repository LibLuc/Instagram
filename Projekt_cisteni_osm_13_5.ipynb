# %%
import pandas as pd
import numpy as np

osmDf = pd.read_csv('osm.csv', encoding='utf-8', delimiter=';')
osmDf.head()
osmDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 12 columns):
# ID               792 non-null int64
# LAT              792 non-null object
# LON              792 non-null object
# NAME             300 non-null object
# TIMESTAMP        783 non-null object
# ADDR_STREET      64 non-null object
# ADDR_CITY        43 non-null object
# ADDR_STATE       0 non-null float64
# ADDR_POSTCODE    60 non-null object
# TAG_KEY          783 non-null object
# TAG_VALUE        779 non-null object
# DISTANCE         783 non-null float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 74.3+ KB

# %%
osmDf.head()
# Out:
#            ID         LAT         LON                  NAME TIMESTAMP  \
# 0  1229196667  50,0902909  14,4494304                   NaN   36:12,0
# 1  1237556564  50,0955973  14,4684661  Studio Divadla Kámen   44:42,0
# 2  1314084713  50,0875412  14,4548586           MATRIX club   19:59,0
# 3  1317088234  50,0935184   14,455158        Můj šálek kávy   57:24,0
# 4  1117933116  50,0922297  14,4426762       Pizzeria Rialto   02:22,0
#
#    ADDR_STREET ADDR_CITY  ADDR_STATE ADDR_POSTCODE  TAG_KEY   TAG_VALUE  \
# 0          NaN       NaN         NaN           NaN  AMENITY   recycling
# 1  Nekvasilova   Praha 8         NaN         18600  AMENITY     theatre
# 2     Koněvova   Praha 3         NaN           NaN  AMENITY   nightclub
# 3     Koněvova     Praha         NaN         18600  AMENITY        cafe
# 4          NaN       NaN         NaN           NaN  AMENITY  restaurant
#
#    DISTANCE
# 0     573.0
# 1     966.0
# 2     701.0
# 3      36.0
# 4     916.0

# %%
osmDf["LAT"] = osmDf["LAT"].replace(',','.', regex=True).astype(np.float)

osmDf.head()
# Out:
#            ID        LAT         LON                  NAME TIMESTAMP  \
# 0  1229196667  50.090291  14,4494304                   NaN   36:12,0
# 1  1237556564  50.095597  14,4684661  Studio Divadla Kámen   44:42,0
# 2  1314084713  50.087541  14,4548586           MATRIX club   19:59,0
# 3  1317088234  50.093518   14,455158        Můj šálek kávy   57:24,0
# 4  1117933116  50.092230  14,4426762       Pizzeria Rialto   02:22,0
#
#    ADDR_STREET ADDR_CITY  ADDR_STATE ADDR_POSTCODE  TAG_KEY   TAG_VALUE  \
# 0          NaN       NaN         NaN           NaN  AMENITY   recycling
# 1  Nekvasilova   Praha 8         NaN         18600  AMENITY     theatre
# 2     Koněvova   Praha 3         NaN           NaN  AMENITY   nightclub
# 3     Koněvova     Praha         NaN         18600  AMENITY        cafe
# 4          NaN       NaN         NaN           NaN  AMENITY  restaurant
#
#    DISTANCE
# 0     573.0
# 1     966.0
# 2     701.0
# 3      36.0
# 4     916.0

# %%
osmDf["LON"] = osmDf["LON"].replace(',','.', regex=True).astype(np.float)

# %%
osmDf.head()
# Out:
#            ID        LAT        LON                  NAME TIMESTAMP  \
# 0  1229196667  50.090291  14.449430                   NaN   36:12,0
# 1  1237556564  50.095597  14.468466  Studio Divadla Kámen   44:42,0
# 2  1314084713  50.087541  14.454859           MATRIX club   19:59,0
# 3  1317088234  50.093518  14.455158        Můj šálek kávy   57:24,0
# 4  1117933116  50.092230  14.442676       Pizzeria Rialto   02:22,0
#
#    ADDR_STREET ADDR_CITY  ADDR_STATE ADDR_POSTCODE  TAG_KEY   TAG_VALUE  \
# 0          NaN       NaN         NaN           NaN  AMENITY   recycling
# 1  Nekvasilova   Praha 8         NaN         18600  AMENITY     theatre
# 2     Koněvova   Praha 3         NaN           NaN  AMENITY   nightclub
# 3     Koněvova     Praha         NaN         18600  AMENITY        cafe
# 4          NaN       NaN         NaN           NaN  AMENITY  restaurant
#
#    DISTANCE
# 0     573.0
# 1     966.0
# 2     701.0
# 3      36.0
# 4     916.0

# %%
osmDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 12 columns):
# ID               792 non-null int64
# LAT              792 non-null float64
# LON              792 non-null float64
# NAME             300 non-null object
# TIMESTAMP        783 non-null object
# ADDR_STREET      64 non-null object
# ADDR_CITY        43 non-null object
# ADDR_STATE       0 non-null float64
# ADDR_POSTCODE    60 non-null object
# TAG_KEY          783 non-null object
# TAG_VALUE        779 non-null object
# DISTANCE         783 non-null float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 74.3+ KB

# %%
osmDf.isnull().sum()
# Out:
# ID                 0
# LAT                0
# LON                0
# NAME             492
# TIMESTAMP          9
# ADDR_STREET      728
# ADDR_CITY        749
# ADDR_STATE       792
# ADDR_POSTCODE    732
# TAG_KEY            9
# TAG_VALUE         13
# DISTANCE           9
# dtype: int64

# %%
osmDf.fillna('Nezadané').head(3)
# Out:
#            ID        LAT        LON                  NAME TIMESTAMP  \
# 0  1229196667  50.090291  14.449430              Nezadané   36:12,0
# 1  1237556564  50.095597  14.468466  Studio Divadla Kámen   44:42,0
# 2  1314084713  50.087541  14.454859           MATRIX club   19:59,0
#
#    ADDR_STREET ADDR_CITY ADDR_STATE ADDR_POSTCODE  TAG_KEY  TAG_VALUE DISTANCE
# 0     Nezadané  Nezadané   Nezadané      Nezadané  AMENITY  recycling      573
# 1  Nekvasilova   Praha 8   Nezadané         18600  AMENITY    theatre      966
# 2     Koněvova   Praha 3   Nezadané      Nezadané  AMENITY  nightclub      701

# %%
osmDf.groupby('NAME').count() # zjisteni poctu lokalit - 266
# Out:
#                                  ID  LAT  LON  TIMESTAMP  ADDR_STREET  \
# NAME
# 1. KáPA                           1    1    1          1            0
# Alabama                           1    1    1          1            0
# Albert                            2    2    2          2            0
# Alien Music bar                   1    1    1          1            1
# Alkohol a cigarety                1    1    1          1            0
# Alza.cz                           1    1    1          1            0
# Amfora                            1    1    1          1            0
# Aron                              1    1    1          1            0
# Asijské bistro Tuan Vu Minh       1    1    1          1            0
# B&B Prague-City Hotel             1    1    1          1            0
# Bageterie                         1    1    1          1            0
# Bageterie Boulevard               1    1    1          1            1
# ...

# %%
osmDf.groupby('ID').count() #764 ID z 792 řádků - nějaké duplicity
# Out:
#             LAT  LON  NAME  TIMESTAMP  ADDR_STREET  ADDR_CITY  ADDR_STATE  \
# ID
# 21311310      1    1     0          1            0          0           0
# 21311321      1    1     0          1            0          0           0
# 21673262      1    1     0          1            0          0           0
# 21673267      1    1     0          1            0          0           0
# 21673271      1    1     0          1            0          0           0
# 21673404      1    1     0          1            0          0           0
# 24569272      1    1     1          0            0          0           0
# 24569287      1    1     1          0            0          0           0
# 24569342      1    1     1          0            0          0           0
# 24958997      1    1     0          1            0          0           0
# 25662315      1    1     0          1            0          0           0
# 25662760      1    1     0          1            0          0           0
# ...

# %%
osmDf.groupby('NAME').ID.describe() 
#zgrupováno podle místa: 266 míst
# Out:
#                                  count          mean           std  \
# NAME
# 1. KáPA                            1.0  1.236483e+09           NaN
# Alabama                            1.0  4.679642e+08           NaN
# Albert                             2.0  1.317603e+09  1.335321e+09
# Alien Music bar                    1.0  3.082106e+09           NaN
# Alkohol a cigarety                 1.0  3.276685e+09           NaN
# Alza.cz                            1.0  2.915624e+08           NaN
# Amfora                             1.0  3.682443e+08           NaN
# Aron                               1.0  1.487327e+09           NaN
# Asijské bistro Tuan Vu Minh        1.0  3.838734e+09           NaN
# B&B Prague-City Hotel              1.0  2.532190e+09           NaN
# Bageterie                          1.0  3.740677e+09           NaN
# Bageterie Boulevard                1.0  3.154112e+09           NaN
# Bajkazyl                           2.0  2.796265e+09  7.071068e-01
# ...

# %%
osmDf["NAME"][osmDf["NAME"] != ''].count() #počet záznamů bez udání místa

#vypiš jen záznamy s udáním místa - pak vypsat místo, GPS pozici, ID, adress, tag key a value
osm_uprava = osmDf[['NAME', 'ID', 'LAT', 'LON', 'TAG_KEY', 'TAG_VALUE', 'ADDR_STREET']][osmDf.NAME != '']

# %%
osm_uprava.head()
# Out:
#                    NAME          ID        LAT        LON  TAG_KEY  \
# 0                   NaN  1229196667  50.090291  14.449430  AMENITY
# 1  Studio Divadla Kámen  1237556564  50.095597  14.468466  AMENITY
# 2           MATRIX club  1314084713  50.087541  14.454859  AMENITY
# 3        Můj šálek kávy  1317088234  50.093518  14.455158  AMENITY
# 4       Pizzeria Rialto  1117933116  50.092230  14.442676  AMENITY
#
#     TAG_VALUE  ADDR_STREET
# 0   recycling          NaN
# 1     theatre  Nekvasilova
# 2   nightclub     Koněvova
# 3        cafe     Koněvova
# 4  restaurant          NaN

# %%
osm_uprava.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 792 entries, 0 to 791
# Data columns (total 7 columns):
# NAME           300 non-null object
# ID             792 non-null int64
# LAT            792 non-null float64
# LON            792 non-null float64
# TAG_KEY        783 non-null object
# TAG_VALUE      779 non-null object
# ADDR_STREET    64 non-null object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 49.5+ KB

# %%
osm_uprava.tail()
# Out:
#                  NAME          ID        LAT        LON        TAG_KEY  \
# 787            Eliška  2691013552  50.100045  14.445842           SHOP
# 788           Ehrlich   307220746  50.089369  14.463043        TOURISM
# 789  GreenYacht Hotel   742443865  50.102100  14.459990        TOURISM
# 790            Meteor   296838175  50.094110  14.452415  UNCATEGORIZED
# 791            Karlín   297896692  50.092409  14.458422  UNCATEGORIZED
#
#          TAG_VALUE         ADDR_STREET
# 787  confectionery                 NaN
# 788          hotel                 NaN
# 789          hotel  U Libeňského mostu
# 790            NaN          Sokolovská
# 791            NaN                 NaN

# %%
osm_cisteDf = pd.DataFrame(osm_uprava)

# %%
osm_cisteDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 792 entries, 0 to 791
# Data columns (total 7 columns):
# NAME           300 non-null object
# ID             792 non-null int64
# LAT            792 non-null float64
# LON            792 non-null float64
# TAG_KEY        783 non-null object
# TAG_VALUE      779 non-null object
# ADDR_STREET    64 non-null object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 49.5+ KB

# %%
osm_cisteDf[(osm_cisteDf["NAME"] != 'NaN')]
# Out:
#                                      NAME          ID        LAT        LON  \
# 0                                     NaN  1229196667  50.090291  14.449430
# 1                    Studio Divadla Kámen  1237556564  50.095597  14.468466
# 2                             MATRIX club  1314084713  50.087541  14.454859
# 3                          Můj šálek kávy  1317088234  50.093518  14.455158
# 4                         Pizzeria Rialto  1117933116  50.092230  14.442676
# 5                                     NaN  1229196569  50.093148  14.447992
# 6                                     NaN  1229196644  50.087441  14.453148
# 7                                     NaN  1252116706  50.085808  14.450650
# 8                              Spirit Bar  1252116709  50.085946  14.448684
# 9                                     NaN  1371440303  50.100808  14.449938
# 10                                    NaN  1239698662  50.090845  14.465198
# ...

# %%
osm_cisteDf[osm_cisteDf["NAME"] =='NaN'].shape
# Out:
# (0, 7)

# %%
osm_cisteDf.notnull().head()
# Out:
#     NAME    ID   LAT   LON  TAG_KEY  TAG_VALUE  ADDR_STREET
# 0  False  True  True  True     True       True        False
# 1   True  True  True  True     True       True         True
# 2   True  True  True  True     True       True         True
# 3   True  True  True  True     True       True         True
# 4   True  True  True  True     True       True        False

# %%
osm_cisteDf.NAME.dropna()
# Out:
# 1                      Studio Divadla Kámen
# 2                               MATRIX club
# 3                            Můj šálek kávy
# 4                           Pizzeria Rialto
# 8                                Spirit Bar
# 11     Městská policie hlavního města Prahy
# 16                               Dhaba Beas
# 17                                     Gate
# 20                   U Karlínského přístavu
# 21                              Dobrá Karma
# 22                                   Amfora
# 23                               Cafe Sonia
# 24                                     ČSOB
# 25                        G a Hudební škola
# 27                           Posta Praha 31
# 32                                    Frida
# 33                            Lokál Hamburk
# 79                  Karel Havlíček Borovský
# 80                       Qarta architektura
# 81                     Monster Worldwide CZ
# 82                              Justiz-Caps
# ...

# %%
osm_cisteDf.head()
# Out:
#                    NAME          ID        LAT        LON  TAG_KEY  \
# 0                   NaN  1229196667  50.090291  14.449430  AMENITY
# 1  Studio Divadla Kámen  1237556564  50.095597  14.468466  AMENITY
# 2           MATRIX club  1314084713  50.087541  14.454859  AMENITY
# 3        Můj šálek kávy  1317088234  50.093518  14.455158  AMENITY
# 4       Pizzeria Rialto  1117933116  50.092230  14.442676  AMENITY
#
#     TAG_VALUE  ADDR_STREET
# 0   recycling          NaN
# 1     theatre  Nekvasilova
# 2   nightclub     Koněvova
# 3        cafe     Koněvova
# 4  restaurant          NaN

# %%
osm_vycistenoDf=osm_cisteDf.fillna('Nezadane')

# %%
osm_vycistenoDf[osm_vycistenoDf["NAME"] == 'Nezadane'].shape
# Out:
# (492, 7)

# %%
osm_finalDf=osm_vycistenoDf[osm_vycistenoDf["NAME"] != 'Nezadane'] #je jich takto 300

# %%
osm_finalDf
# Out:
#                                      NAME          ID        LAT        LON  \
# 1                    Studio Divadla Kámen  1237556564  50.095597  14.468466
# 2                             MATRIX club  1314084713  50.087541  14.454859
# 3                          Můj šálek kávy  1317088234  50.093518  14.455158
# 4                         Pizzeria Rialto  1117933116  50.092230  14.442676
# 8                              Spirit Bar  1252116709  50.085946  14.448684
# 11   Městská policie hlavního města Prahy  1252116711  50.085807  14.450582
# 16                             Dhaba Beas  1702407020  50.094404  14.452373
# 17                                   Gate  1117933121  50.092182  14.442397
# 20                 U Karlínského přístavu   368244504  50.093483  14.448069
# 21                            Dobrá Karma  3726614863  50.084868  14.454765
# 22                                 Amfora   368244318  50.093588  14.448627
# ...

# %%
osm_finalDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300 entries, 1 to 791
# Data columns (total 7 columns):
# NAME           300 non-null object
# ID             300 non-null int64
# LAT            300 non-null float64
# LON            300 non-null float64
# TAG_KEY        300 non-null object
# TAG_VALUE      300 non-null object
# ADDR_STREET    300 non-null object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 18.8+ KB

# %%
osm_finalDf["NAME"].count()
# Out:
# 300

# %%
osm_finalDf.groupby('NAME').count() #je tam 34 duplicit - co s tím?
# Out:
#                                  ID  LAT  LON  TAG_KEY  TAG_VALUE  ADDR_STREET
# NAME
# 1. KáPA                           1    1    1        1          1            1
# Alabama                           1    1    1        1          1            1
# Albert                            2    2    2        2          2            2
# Alien Music bar                   1    1    1        1          1            1
# Alkohol a cigarety                1    1    1        1          1            1
# Alza.cz                           1    1    1        1          1            1
# Amfora                            1    1    1        1          1            1
# Aron                              1    1    1        1          1            1
# Asijské bistro Tuan Vu Minh       1    1    1        1          1            1
# B&B Prague-City Hotel             1    1    1        1          1            1
# Bageterie                         1    1    1        1          1            1
# ...

# %%
osm_finalDf1=osm_finalDf.drop_duplicates("NAME", keep='first', inplace=False)

osm_finalDf1.head()

osm_finalDf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 266 entries, 1 to 791
# Data columns (total 7 columns):
# NAME           266 non-null object
# ID             266 non-null int64
# LAT            266 non-null float64
# LON            266 non-null float64
# TAG_KEY        266 non-null object
# TAG_VALUE      266 non-null object
# ADDR_STREET    266 non-null object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 16.6+ KB

# %%
osm_finalDf1.groupby('NAME').count()
# Out:
#                                  ID  LAT  LON  TAG_KEY  TAG_VALUE  ADDR_STREET
# NAME
# 1. KáPA                           1    1    1        1          1            1
# Alabama                           1    1    1        1          1            1
# Albert                            1    1    1        1          1            1
# Alien Music bar                   1    1    1        1          1            1
# Alkohol a cigarety                1    1    1        1          1            1
# Alza.cz                           1    1    1        1          1            1
# Amfora                            1    1    1        1          1            1
# Aron                              1    1    1        1          1            1
# Asijské bistro Tuan Vu Minh       1    1    1        1          1            1
# B&B Prague-City Hotel             1    1    1        1          1            1
# Bageterie                         1    1    1        1          1            1
# ...

# %%
osm_finalDf1.groupby('TAG_KEY').count()
# Out:
#                NAME   ID  LAT  LON  TAG_VALUE  ADDR_STREET
# TAG_KEY
# AMENITY         132  132  132  132        132          132
# BUILDING          1    1    1    1          1            1
# HIGHWAY           6    6    6    6          6            6
# HISTORIC          3    3    3    3          3            3
# LEISURE           2    2    2    2          2            2
# MAN_MADE         38   38   38   38         38           38
# Nezadane          7    7    7    7          7            7
# OFFICE            6    6    6    6          6            6
# RAILWAY           3    3    3    3          3            3
# SHOP             40   40   40   40         40           40
# SPORT             2    2    2    2          2            2
# TOURISM          22   22   22   22         22           22
# UNCATEGORIZED     4    4    4    4          4            4

# %%
osm_finalDf1.to_csv('osm_final.csv', encoding='utf-8', index=False)
