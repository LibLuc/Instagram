# %%
import pandas as pd

# %%
hashdf = pd.read_csv('hashtag.csv', encoding='utf-8', delimiter=',')
p1df = pd.read_csv('refine_ciste_post.csv', encoding='utf-8', delimiter=',')

# %%
p1df
# Out:
#        index  longitude   latitude  \
# 0          0  14.456625  50.087918
# 1          1  14.446800  50.091440
# 2          2  14.449982  50.088717
# 3          3  14.449444  50.088333
# 4          4  14.449982  50.088717
# 5          5  14.449982  50.088717
# 6          6  14.449982  50.088717
# 7          7  14.450020  50.088540
# 8          8  14.453450  50.087700
# 9          9  14.450000  50.100000
# 10        10  14.456850  50.093970
# 11        11  14.452470  50.086810
# 12        12  14.454588  50.091525
# 13        13  14.454410  50.091351
# 14        14  14.454410  50.091351
# 15        15  14.450000  50.100000
# 16        16  14.456324  50.093436
# 17        17  14.454759  50.094598
# 18        18  14.457250  50.094051
# 19        19  14.453410  50.092470
# 20        20  14.454410  50.091351
# 21        21  14.456850  50.093970
# 22        22  14.452150  50.091210
# 23        23  14.454388  50.093194
# 24        24  14.451549  50.094022
# ...

# %%
hashdf
# Out:
#        index  match hashtag                  1
# 0          1      0       #             prague
# 1          1      1       #               food
# 2          1      2       #            brother
# 3          1      3       #             sister
# 4          1      4       #             family
# 5          1      5       #              happy
# 6          1      6       #               late
# 7          1      7       #              lunch
# 8          1      8       #             burger
# 9          1      9       #        frenchfries
# 10         1     10       #          delicious
# 11         1     11       #               week
# 12         1     12       #             spring
# 13         1     13       #           foodpics
# 14         1     14       #     foodeverywhere
# 15         1     15       #          like4like
# 16         1     16       #    followforfollow
# 17         1     17       #      follow4follow
# 18         1     18       #                f4f
# ...

# %%
new = pd.merge(p1df, hashdf, on='index', how='outer', suffixes=('_p', '_h'))
new
# Out:
#        index  longitude   latitude  \
# 0          0  14.456625  50.087918
# 1          1  14.446800  50.091440
# 2          1  14.446800  50.091440
# 3          1  14.446800  50.091440
# 4          1  14.446800  50.091440
# 5          1  14.446800  50.091440
# 6          1  14.446800  50.091440
# 7          1  14.446800  50.091440
# 8          1  14.446800  50.091440
# 9          1  14.446800  50.091440
# 10         1  14.446800  50.091440
# 11         1  14.446800  50.091440
# 12         1  14.446800  50.091440
# 13         1  14.446800  50.091440
# 14         1  14.446800  50.091440
# 15         1  14.446800  50.091440
# 16         1  14.446800  50.091440
# 17         1  14.446800  50.091440
# 18         1  14.446800  50.091440
# 19         1  14.446800  50.091440
# 20         1  14.446800  50.091440
# 21         1  14.446800  50.091440
# 22         1  14.446800  50.091440
# 23         1  14.446800  50.091440
# 24         2  14.449982  50.088717
# ...

# %%
transnew = new
transnew.to_csv('hash_posts.csv', encoding='utf-8', index=False)
