# %%
import pandas as pd
import datetime as dt
import numpy as np
import calendar

# %%
ciste_posts = pd.read_csv('refine_ciste_post.csv', delimiter=',', encoding='utf-8')
ciste_posts
# Out:
#        index  longitude   latitude  \
# 0          0  14.456625  50.087918
# 1          1  14.446800  50.091440
# 2          2  14.449982  50.088717
# 3          3  14.449444  50.088333
# 4          4  14.449982  50.088717
# 5          5  14.449982  50.088717
# 6          6  14.449982  50.088717
# 7          7  14.450020  50.088540
# 8          8  14.453450  50.087700
# 9          9  14.450000  50.100000
# 10        10  14.456850  50.093970
# 11        11  14.452470  50.086810
# 12        12  14.454588  50.091525
# 13        13  14.454410  50.091351
# 14        14  14.454410  50.091351
# 15        15  14.450000  50.100000
# 16        16  14.456324  50.093436
# 17        17  14.454759  50.094598
# 18        18  14.457250  50.094051
# 19        19  14.453410  50.092470
# 20        20  14.454410  50.091351
# 21        21  14.456850  50.093970
# 22        22  14.452150  50.091210
# 23        23  14.454388  50.093194
# 24        24  14.451549  50.094022
# ...

# %%
ciste_posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10255 entries, 0 to 10254
# Data columns (total 14 columns):
# index             10255 non-null int64
# longitude         10255 non-null float64
# latitude          10255 non-null float64
# location_name     10229 non-null object
# location_id       10255 non-null int64
# username          10244 non-null object
# user_fullname     8718 non-null object
# created_time      10255 non-null object
# comments_count    10255 non-null int64
# likes_count       10255 non-null int64
# link              10255 non-null object
# user_id           10244 non-null float64
# id                10244 non-null object
# weekday           10255 non-null object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 1.1+ MB

# %%
all_columns = list(ciste_posts.columns) + ['time'] #přidání sloupce s časem
ciste_posts = pd.DataFrame(ciste_posts, columns=all_columns)

# %%
ciste_posts.head()
# Out:
#    index  longitude   latitude  \
# 0      0  14.456625  50.087918
# 1      1  14.446800  50.091440
# 2      2  14.449982  50.088717
# 3      3  14.449444  50.088333
# 4      4  14.449982  50.088717
#
#                                        location_name  location_id  \
# 0                                        Dobrá Trefa     42486175
# 1                                       Nejen Bistro    925837042
# 2  Národní památník Vítkov (National Monument in ...    503342919
# 3                                                NaN   1016818575
# 4  Národní památník Vítkov (National Monument in ...    503342919
#
#            username      user_fullname         created_time  comments_count  \
# 0      david.k.busa   David Koala Buša  2016-03-30 23:38:00               0
# 1        anysmile28                Any  2016-03-30 23:26:00               2
# 2  yannicschiketanz  Yannic Schikeatnz  2016-03-30 23:25:00               1
# ...

# %%
#ciste_posts["created_time"] = pd.to_datetime(ciste_posts["created_time"])
#ciste_posts.info()

# %%
ciste_posts["time"] = ciste_posts["created_time"]
ciste_posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10255 entries, 0 to 10254
# Data columns (total 15 columns):
# index             10255 non-null int64
# longitude         10255 non-null float64
# latitude          10255 non-null float64
# location_name     10229 non-null object
# location_id       10255 non-null int64
# username          10244 non-null object
# user_fullname     8718 non-null object
# created_time      10255 non-null object
# comments_count    10255 non-null int64
# likes_count       10255 non-null int64
# link              10255 non-null object
# user_id           10244 non-null float64
# id                10244 non-null object
# weekday           10255 non-null object
# time              10255 non-null object
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
#ciste_posts["created_time"] = pd.to_datetime(ciste_posts["created_time"])
ciste_posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10255 entries, 0 to 10254
# Data columns (total 15 columns):
# index             10255 non-null int64
# longitude         10255 non-null float64
# latitude          10255 non-null float64
# location_name     10229 non-null object
# location_id       10255 non-null int64
# username          10244 non-null object
# user_fullname     8718 non-null object
# created_time      10255 non-null object
# comments_count    10255 non-null int64
# likes_count       10255 non-null int64
# link              10255 non-null object
# user_id           10244 non-null float64
# id                10244 non-null object
# weekday           10255 non-null object
# time              10255 non-null object
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
ciste_posts = ciste_posts.rename({"created_time":"date"}, axis=1) ##??? proč se nepřejmenoval???

# %%
ciste_posts.head()
# Out:
#    index  longitude   latitude  \
# 0      0  14.456625  50.087918
# 1      1  14.446800  50.091440
# 2      2  14.449982  50.088717
# 3      3  14.449444  50.088333
# 4      4  14.449982  50.088717
#
#                                        location_name  location_id  \
# 0                                        Dobrá Trefa     42486175
# 1                                       Nejen Bistro    925837042
# 2  Národní památník Vítkov (National Monument in ...    503342919
# 3                                                NaN   1016818575
# 4  Národní památník Vítkov (National Monument in ...    503342919
#
#            username      user_fullname                 date  comments_count  \
# 0      david.k.busa   David Koala Buša  2016-03-30 23:38:00               0
# 1        anysmile28                Any  2016-03-30 23:26:00               2
# 2  yannicschiketanz  Yannic Schikeatnz  2016-03-30 23:25:00               1
# ...

# %%
ciste_posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10255 entries, 0 to 10254
# Data columns (total 15 columns):
# index             10255 non-null int64
# longitude         10255 non-null float64
# latitude          10255 non-null float64
# location_name     10229 non-null object
# location_id       10255 non-null int64
# username          10244 non-null object
# user_fullname     8718 non-null object
# date              10255 non-null object
# comments_count    10255 non-null int64
# likes_count       10255 non-null int64
# link              10255 non-null object
# user_id           10244 non-null float64
# id                10244 non-null object
# weekday           10255 non-null object
# time              10255 non-null object
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
ciste_posts['date'] = pd.to_datetime(ciste_posts['date']).dt.date #odseparuje časový údaj

# %%
ciste_posts.head()
# Out:
#    index  longitude   latitude  \
# 0      0  14.456625  50.087918
# 1      1  14.446800  50.091440
# 2      2  14.449982  50.088717
# 3      3  14.449444  50.088333
# 4      4  14.449982  50.088717
#
#                                        location_name  location_id  \
# 0                                        Dobrá Trefa     42486175
# 1                                       Nejen Bistro    925837042
# 2  Národní památník Vítkov (National Monument in ...    503342919
# 3                                                NaN   1016818575
# 4  Národní památník Vítkov (National Monument in ...    503342919
#
#            username      user_fullname        date  comments_count  \
# 0      david.k.busa   David Koala Buša  2016-03-30               0
# 1        anysmile28                Any  2016-03-30               2
# 2  yannicschiketanz  Yannic Schikeatnz  2016-03-30               1
# 3      krychkova_mv               mary  2016-03-30               0
# ...

# %%
all_columns = list(ciste_posts.columns) + ['day','month'] #přidání sloupce se dny a mesici
ciste_posts = pd.DataFrame(ciste_posts, columns=all_columns)

# %%
ciste_posts.head()
# Out:
#    index  longitude   latitude  \
# 0      0  14.456625  50.087918
# 1      1  14.446800  50.091440
# 2      2  14.449982  50.088717
# 3      3  14.449444  50.088333
# 4      4  14.449982  50.088717
#
#                                        location_name  location_id  \
# 0                                        Dobrá Trefa     42486175
# 1                                       Nejen Bistro    925837042
# 2  Národní památník Vítkov (National Monument in ...    503342919
# 3                                                NaN   1016818575
# 4  Národní památník Vítkov (National Monument in ...    503342919
#
#            username      user_fullname        date  comments_count  \
# 0      david.k.busa   David Koala Buša  2016-03-30               0
# 1        anysmile28                Any  2016-03-30               2
# 2  yannicschiketanz  Yannic Schikeatnz  2016-03-30               1
# 3      krychkova_mv               mary  2016-03-30               0
# ...

# %%
ciste_posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10255 entries, 0 to 10254
# Data columns (total 17 columns):
# index             10255 non-null int64
# longitude         10255 non-null float64
# latitude          10255 non-null float64
# location_name     10229 non-null object
# location_id       10255 non-null int64
# username          10244 non-null object
# user_fullname     8718 non-null object
# date              10255 non-null object
# comments_count    10255 non-null int64
# likes_count       10255 non-null int64
# link              10255 non-null object
# user_id           10244 non-null float64
# id                10244 non-null object
# weekday           10255 non-null object
# time              10255 non-null object
# day               0 non-null float64
# month             0 non-null float64
# dtypes: float64(5), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
ciste_posts['date'] = pd.to_datetime(ciste_posts['date'])

# %%
ciste_posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10255 entries, 0 to 10254
# Data columns (total 17 columns):
# index             10255 non-null int64
# longitude         10255 non-null float64
# latitude          10255 non-null float64
# location_name     10229 non-null object
# location_id       10255 non-null int64
# username          10244 non-null object
# user_fullname     8718 non-null object
# date              10255 non-null datetime64[ns]
# comments_count    10255 non-null int64
# likes_count       10255 non-null int64
# link              10255 non-null object
# user_id           10244 non-null float64
# id                10244 non-null object
# weekday           10255 non-null object
# time              10255 non-null object
# day               0 non-null float64
# month             0 non-null float64
# dtypes: datetime64[ns](1), float64(5), int64(4), object(7)
# memory usage: 1.3+ MB

# %%
#vyplnění dnů a měsíců
ciste_posts["day"] = ciste_posts["date"].dt.day.astype(np.int)
ciste_posts["month"] = ciste_posts["date"].dt.month.astype(np.int)
ciste_posts.head()
# Out:
#    index  longitude   latitude  \
# 0      0  14.456625  50.087918
# 1      1  14.446800  50.091440
# 2      2  14.449982  50.088717
# 3      3  14.449444  50.088333
# 4      4  14.449982  50.088717
#
#                                        location_name  location_id  \
# 0                                        Dobrá Trefa     42486175
# 1                                       Nejen Bistro    925837042
# 2  Národní památník Vítkov (National Monument in ...    503342919
# 3                                                NaN   1016818575
# 4  Národní památník Vítkov (National Monument in ...    503342919
#
#            username      user_fullname       date  comments_count  \
# 0      david.k.busa   David Koala Buša 2016-03-30               0
# 1        anysmile28                Any 2016-03-30               2
# 2  yannicschiketanz  Yannic Schikeatnz 2016-03-30               1
# 3      krychkova_mv               mary 2016-03-30               0
# ...

# %%
ciste_posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10255 entries, 0 to 10254
# Data columns (total 17 columns):
# index             10255 non-null int64
# longitude         10255 non-null float64
# latitude          10255 non-null float64
# location_name     10229 non-null object
# location_id       10255 non-null int64
# username          10244 non-null object
# user_fullname     8718 non-null object
# date              10255 non-null datetime64[ns]
# comments_count    10255 non-null int64
# likes_count       10255 non-null int64
# link              10255 non-null object
# user_id           10244 non-null float64
# id                10244 non-null object
# weekday           10255 non-null object
# time              10255 non-null object
# day               10255 non-null int32
# month             10255 non-null int32
# dtypes: datetime64[ns](1), float64(3), int32(2), int64(4), object(7)
# memory usage: 1.3+ MB

# %%
svatky = pd.read_csv('days.csv', delimiter=',', encoding='utf-8')

# %%
svatky.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 6 columns):
# Date               366 non-null object
# Day                366 non-null int64
# Month              366 non-null int64
# Year               366 non-null int64
# Weekday            366 non-null int64
# CZ_Holiday_Flag    366 non-null bool
# dtypes: bool(1), int64(4), object(1)
# memory usage: 14.7+ KB

# %%
svatky.head()
# Out:
#          Date  Day  Month  Year  Weekday  CZ_Holiday_Flag
# 0  2016-01-01    1      1  2016        5             True
# 1  2016-01-02    2      1  2016        6            False
# 2  2016-01-03    3      1  2016        7            False
# 3  2016-01-04    4      1  2016        1            False
# 4  2016-01-05    5      1  2016        2            False

# %%
#ciste_posts["date"] = pd.to_datetime(ciste_posts["date"])

# %%
svatky["Date"] = pd.to_datetime(svatky["Date"])

# %%
svatky = pd.DataFrame(svatky, columns=['Date', 'CZ_Holiday_Flag'])
svatky.head()
# Out:
#         Date  CZ_Holiday_Flag
# 0 2016-01-01             True
# 1 2016-01-02            False
# 2 2016-01-03            False
# 3 2016-01-04            False
# 4 2016-01-05            False

# %%
svatky = svatky.rename({"Date":"date"}, axis=1)

# %%
ciste_posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10255 entries, 0 to 10254
# Data columns (total 17 columns):
# index             10255 non-null int64
# longitude         10255 non-null float64
# latitude          10255 non-null float64
# location_name     10229 non-null object
# location_id       10255 non-null int64
# username          10244 non-null object
# user_fullname     8718 non-null object
# date              10255 non-null datetime64[ns]
# comments_count    10255 non-null int64
# likes_count       10255 non-null int64
# link              10255 non-null object
# user_id           10244 non-null float64
# id                10244 non-null object
# weekday           10255 non-null object
# time              10255 non-null object
# day               10255 non-null int32
# month             10255 non-null int32
# dtypes: datetime64[ns](1), float64(3), int32(2), int64(4), object(7)
# memory usage: 1.3+ MB

# %%
svatky.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 2 columns):
# date               366 non-null datetime64[ns]
# CZ_Holiday_Flag    366 non-null bool
# dtypes: bool(1), datetime64[ns](1)
# memory usage: 3.3 KB

# %%
final = pd.merge(ciste_posts, svatky, how ='left', on = ['date'])
final
#new = pd.merge(ciste_posts, svatky, on='date', how='outer', suffixes=('_p', '_h'))
#new
# Out:
#        index  longitude   latitude  \
# 0          0  14.456625  50.087918
# 1          1  14.446800  50.091440
# 2          2  14.449982  50.088717
# 3          3  14.449444  50.088333
# 4          4  14.449982  50.088717
# 5          5  14.449982  50.088717
# 6          6  14.449982  50.088717
# 7          7  14.450020  50.088540
# 8          8  14.453450  50.087700
# 9          9  14.450000  50.100000
# 10        10  14.456850  50.093970
# 11        11  14.452470  50.086810
# 12        12  14.454588  50.091525
# 13        13  14.454410  50.091351
# 14        14  14.454410  50.091351
# 15        15  14.450000  50.100000
# 16        16  14.456324  50.093436
# 17        17  14.454759  50.094598
# 18        18  14.457250  50.094051
# 19        19  14.453410  50.092470
# 20        20  14.454410  50.091351
# 21        21  14.456850  50.093970
# 22        22  14.452150  50.091210
# 23        23  14.454388  50.093194
# 24        24  14.451549  50.094022
# ...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10255 entries, 0 to 10254
# Data columns (total 18 columns):
# index              10255 non-null int64
# longitude          10255 non-null float64
# latitude           10255 non-null float64
# location_name      10229 non-null object
# location_id        10255 non-null int64
# username           10244 non-null object
# user_fullname      8718 non-null object
# date               10255 non-null datetime64[ns]
# comments_count     10255 non-null int64
# likes_count        10255 non-null int64
# link               10255 non-null object
# user_id            10244 non-null float64
# id                 10244 non-null object
# weekday            10255 non-null object
# time               10255 non-null object
# day                10255 non-null int32
# month              10255 non-null int32
# CZ_Holiday_Flag    10255 non-null bool
# dtypes: bool(1), datetime64[ns](1), float64(3), int32(2), int64(4), object(7)
# memory usage: 1.3+ MB

# %%
final.to_csv('svatky.csv', encoding='utf-8', index=False)
